# %% [markdown]
# ./.venv/Scripts/Activate
# cd .\data_car_number_labels\
# yolo detect train data=data.yaml model=yolo26n.pt epochs=50 name='car_number_100326_ep50'

# %%
# %pip install easyocr
# Out:
# ...
#   Using cached easyocr-1.7.2-py3-none-any.whl (2.9 MB)
# ...
#   Using cached opencv_python_headless-4.13.0.92-cp37-abi3-win_amd64.whl (40.1 MB)
# ...
#   Using cached scikit_image-0.26.0-cp311-cp311-win_amd64.whl (11.9 MB)
# ...
#   Using cached ninja-1.13.0-py3-none-win_amd64.whl (309 kB)
# ...
#   Using cached imageio-2.37.3-py3-none-any.whl (317 kB)
# ...
#   Using cached lazy_loader-0.5-py3-none-any.whl (8.0 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import easyocr

# %%
reader = easyocr.Reader(['ru', 'en'])

path_img_test = 'autoriaNumberplateOcrRu\\test\\img\\A003CX196.png'

result = reader.readtext(path_img_test)
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# c:\Users\Яков\Desktop\project2\.venv\Lib\site-packages\torch\utils\data\dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)

# %%
import matplotlib.pyplot as plt

import cv2

img_test = cv2.imread(path_img_test)

plt.title(result[0][1])
plt.imshow(img_test)
plt.show()
